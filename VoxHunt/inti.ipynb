# %%
import os

# %%
import rpy2
import rpy2.robjects as robjects
from rpy2.robjects import pandas2ri
from rpy2.robjects.conversion import localconverter
pandas2ri.activate()
# %load_ext rpy2.ipython

# %%
wd_dir = '/beegfs/scratch/ric.broccoli/kubacki.michal/SRF_SRRM3'
os.chdir(wd_dir)

# %%
# %%R
# library(devtools)
# devtools::install_github('immunogenomics/presto')
# devtools::install_github('quadbiolab/voxhunt')

# %%
# %%R
# library(patchwork)
# library(tidyverse)
# library(voxhunt)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Attaching package: ‘voxhunt’
#
# The following object is masked from ‘package:patchwork’:
#
#     plot_annotation
#
# In addition: Warning messages:
# 1: replacing previous import ‘Matrix::unpack’ by ‘tidyr::unpack’ when loading ‘voxhunt’
# 2: replacing previous import ‘Matrix::expand’ by ‘tidyr::expand’ when loading ‘voxhunt’
# 3: replacing previous import ‘Matrix::pack’ by ‘tidyr::pack’ when loading ‘voxhunt’

# %%
# %%R
# setwd('/beegfs/scratch/ric.broccoli/kubacki.michal/SRF_SRRM3')
# load_aba_data('/beegfs/scratch/ric.broccoli/kubacki.michal/SRF_SRRM3/DATA/vox_hunt/voxhunt_rds')
# Out:
# In addition: Warning message:
# In load_aba_data("/beegfs/scratch/ric.broccoli/kubacki.michal/SRF_SRRM3/DATA/vox_hunt/voxhunt_rds") :
# ...

# %%
# %%R
# p1 <- voxhunt::plot_annotation('E13')
# p2 <- voxhunt::plot_annotation('P4', show_legend=T)
# p1 + p2

# %%
# %%R
# genes <- c('NEUROD6', 'EOMES', 'DCN', 'DLX1', 'DLX2', 'GBX2', 'OTX2', 'GATA3', 'PAX8')
# plot_expression('E15', genes = genes) & no_legend()

# %%
# %%R
# genes <- c('SRRM', "SRRM") # Fixed typo in SRRM4
# plot_expression('P4', genes = genes, fuzzy_match = TRUE) & no_legend()
# Out:
# Error in plot_expression("P4", genes = genes, fuzzy_match = TRUE) :
#   Unfortunately, none of the provided genes were found in the ABA.
# In addition: Warning message:
# In plot_expression("P4", genes = genes, fuzzy_match = TRUE) :
#   The following genes were not found in the ABA: SRRM, SRRM
# Error in plot_expression("P4", genes = genes, fuzzy_match = TRUE) :
#   Unfortunately, none of the provided genes were found in the ABA.
# ---------------------------------------------------------------------------
# RRuntimeError                             Traceback (most recent call last)
# File ~/.conda/envs/jupyter_nb/lib/python3.11/site-packages/rpy2/ipython/rmagic.py:407, in RMagics.eval(self, code)
#     406     r_expr = ri.parse(code)
# --> 407     value, visible = ri.evalr_expr_with_visible(
#     408         r_expr
#     409     )
#     410 except (ri.embedded.RRuntimeError, ValueError) as exception:
#     411     # Otherwise next return seems to have copy of error.
#
# ...
